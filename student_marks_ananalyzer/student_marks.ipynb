# %%
# %pip install numpy
import numpy as np

# %%
marks = np.array([98,94,94,83,82,95,83,92,93,84])

# %%
print("Marks array" , marks)
print("total students", marks.size)
print("array shape", marks.shape)
# Out:
# Marks array [98 94 94 83 82 95 83 92 93 84]
# total students 10
# array shape (10,)

# %%
print("class avg marks",np.mean(marks))
# Out:
# class avg marks 89.8

# %%
print("highest marks in the class ",np.max(marks))
# Out:
# highest marks in the class  98

# %%
print("lowest score in the class",np.min(marks))
# Out:
# lowest score in the class 82

# %%
print("total score by the class ",np.sum(marks))
# Out:
# total score by the class  898

# %%
print("student who scored the hghest marks is ",np.argmax(marks),"and the marks scored are ",marks[np.argmax(marks)])
# Out:
# student who scored the hghest marks is  0 and the marks scored are  98

# %%
print("student who socred the min marks is",np.argmin(marks),"and the marks are",marks[np.argmin(marks)])
# Out:
# student who socred the min marks is 4 and the marks are 82

# %%
passstud = marks[marks>=85]
passstud
# Out:
# array([98, 94, 94, 95, 92, 93])

# %%
stupassed = passstud.size
stupassed
# Out:
# 6

# %%
sumofpassno = np.sum(passstud)

# %%
passper = (stupassed/marks.size)*100
passper
# Out:
# 60.0

# %%
np.clip(marks+5 , a_min = 0, a_max = 100)
# Out:
# array([100,  99,  99,  88,  87, 100,  88,  97,  98,  89])
